# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import time
import glob
import warnings
warnings.filterwarnings('ignore')


#data
path = "./data/data_test"
all_files = glob.glob(path + "/*.csv")   #把所有的数据文件文件名读取在一起

li = []


for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)


frame = pd.concat(li, axis=0, ignore_index=True)
result_df = frame.sort_values(by=['date', 'code'], ascending=True)
result_df['vwap'] = result_df['money'] / result_df['volume']
result_df['target'] = result_df.groupby('code')['1vwap_pct'].shift(-1).values
df = result_df.reset_index(drop=True)
df = df.fillna(0)
# df_train = df[(df['date'] <= '2022-04-30')]
# df_test = df[(df['date'] <= '2022-12-29') & (df['date'] >= '2022-05-01')]
df_train = df[(df['date'] >= '2022-11-31') & (df['date'] <= '2022-12-22')]
df_val = df[(df['date'] <= '2022-12-25') & (df['date'] >= '2022-12-23')]
df_test = df[(df['date'] <= '2022-12-29') & (df['date'] >= '2022-12-26')]

X_train = df_train[['open', 'close', 'low', 'high']].values
y_train = df_train[['target']].values
X_val = df_val[['open', 'close', 'low', 'high']].values
y_val = df_val[['target']].values
X_test = df_test[['open', 'close', 'low', 'high']].values
y_test = df_test[['target']].values

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import torch
import torch.nn as nn


# 定义基础模型
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)

# 训练基础模型
rf_model.fit(X_train, y_train)
gb_model.fit(X_train, y_train)

# 得到基础模型在验证集上的预测结果
rf_pred = rf_model.predict(X_val)
gb_pred = gb_model.predict(X_val)

# 构造元特征
meta_features = np.column_stack((rf_pred, gb_pred))

# 定义元模型
class MetaModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MetaModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, output_dim)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.activation(x)
        x = self.fc2(x)
        return x

# 将元特征转换为PyTorch张量
X_meta_tensor = torch.tensor(meta_features, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32)

# 定义元模型的输入维度和隐藏层维度
input_dim = meta_features.shape[1]
hidden_dim = 8

# 初始化元模型
meta_model = MetaModel(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=1)

# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(meta_model.parameters(), lr=0.001)

# 训练元模型
for epoch in range(100):
    optimizer.zero_grad()
    y_pred = meta_model(X_meta_tensor)
    loss = criterion(y_pred.squeeze(), y_val_tensor)  # 去掉无关的维度
    loss.backward()
    optimizer.step()

# 测试集上的预测
rf_test_pred = rf_model.predict(X_test)
gb_test_pred = gb_model.predict(X_test)
meta_features_test = np.column_stack((rf_test_pred, gb_test_pred))
X_meta_test_tensor = torch.tensor(meta_features_test, dtype=torch.float32)
y_test_pred = meta_model(X_meta_test_tensor).detach().numpy()

# 计算测试集上的均方误差
mse_test = mean_squared_error(y_test, y_test_pred)
print("Test MSE:", mse_test)
# Out:
# Test MSE: 7.71455662725422

# %%
import numpy as np
from sklearn.ensemble import VotingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.metrics import mean_squared_error


# 初始化三个模型
xgb_model = XGBRegressor()
catboost_model = CatBoostRegressor()
bayesian_ridge_model = BayesianRidge()

# 创建投票回归器
voting_regressor = VotingRegressor(
    estimators=[
        ('xgb', xgb_model),
        ('catboost', catboost_model),
        ('bayesian_ridge', bayesian_ridge_model)
    ],
    weights=[1, 1, 1]  # 可以根据模型性能调整权重
)

# 训练投票回归器
voting_regressor.fit(X_train, y_train)

# 在测试集上进行预测
y_pred = voting_regressor.predict(X_test)

# 评估模型性能
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Learning rate set to 0.0815
# 0:	learn: 2.5697972	total: 57.1ms	remaining: 57.1s
# 1:	learn: 2.5696507	total: 63.8ms	remaining: 31.8s
# 2:	learn: 2.5695941	total: 68.8ms	remaining: 22.9s
# 3:	learn: 2.5695437	total: 73.3ms	remaining: 18.3s
# 4:	learn: 2.5694578	total: 78.5ms	remaining: 15.6s
# 5:	learn: 2.5693859	total: 83.6ms	remaining: 13.8s
# 6:	learn: 2.5692315	total: 88.4ms	remaining: 12.5s
# 7:	learn: 2.5691918	total: 93.2ms	remaining: 11.6s
# 8:	learn: 2.5690935	total: 97.9ms	remaining: 10.8s
# 9:	learn: 2.5689560	total: 103ms	remaining: 10.2s
# 10:	learn: 2.5688614	total: 107ms	remaining: 9.66s
# 11:	learn: 2.5687732	total: 112ms	remaining: 9.22s
# 12:	learn: 2.5686027	total: 117ms	remaining: 8.89s
# 13:	learn: 2.5684551	total: 122ms	remaining: 8.57s
# 14:	learn: 2.5681949	total: 127ms	remaining: 8.34s
# 15:	learn: 2.5681026	total: 132ms	remaining: 8.11s
# 16:	learn: 2.5679960	total: 137ms	remaining: 7.89s
# 17:	learn: 2.5677970	total: 141ms	remaining: 7.67s
# 18:	learn: 2.5676401	total: 145ms	remaining: 7.49s
# 19:	learn: 2.5674812	total: 150ms	remaining: 7.35s
# 20:	learn: 2.5673890	total: 155ms	remaining: 7.21s
# 21:	learn: 2.5672597	total: 159ms	remaining: 7.07s
# 22:	learn: 2.5671500	total: 163ms	remaining: 6.93s
# 23:	learn: 2.5669809	total: 167ms	remaining: 6.8s
# 24:	learn: 2.5668829	total: 171ms	remaining: 6.68s
# 25:	learn: 2.5668177	total: 176ms	remaining: 6.59s
# 26:	learn: 2.5667438	total: 180ms	remaining: 6.49s
# 27:	learn: 2.5666362	total: 184ms	remaining: 6.39s
# 28:	learn: 2.5664277	total: 188ms	remaining: 6.29s
# 29:	learn: 2.5663106	total: 192ms	remaining: 6.22s
# 30:	learn: 2.5662107	total: 196ms	remaining: 6.14s
# 31:	learn: 2.5660682	total: 201ms	remaining: 6.07s
# 32:	learn: 2.5659118	total: 205ms	remaining: 5.99s
# 33:	learn: 2.5657009	total: 209ms	remaining: 5.93s
# 34:	learn: 2.5655215	total: 213ms	remaining: 5.87s
# 35:	learn: 2.5654483	total: 217ms	remaining: 5.81s
# 36:	learn: 2.5653586	total: 221ms	remaining: 5.75s
# 37:	learn: 2.5653134	total: 225ms	remaining: 5.69s
# 38:	learn: 2.5652227	total: 229ms	remaining: 5.63s
# 39:	learn: 2.5651334	total: 232ms	remaining: 5.58s
# 40:	learn: 2.5649576	total: 236ms	remaining: 5.53s
# 41:	learn: 2.5646819	total: 242ms	remaining: 5.51s
# 42:	learn: 2.5645928	total: 248ms	remaining: 5.53s
# 43:	learn: 2.5643687	total: 256ms	remaining: 5.56s
# 44:	learn: 2.5642546	total: 261ms	remaining: 5.53s
# 45:	learn: 2.5639188	total: 265ms	remaining: 5.5s
# 46:	learn: 2.5638521	total: 269ms	remaining: 5.46s
# 47:	learn: 2.5636964	total: 273ms	remaining: 5.41s
# 48:	learn: 2.5636405	total: 277ms	remaining: 5.37s
# 49:	learn: 2.5634281	total: 280ms	remaining: 5.33s
# 50:	learn: 2.5633005	total: 284ms	remaining: 5.29s
# 51:	learn: 2.5631719	total: 288ms	remaining: 5.25s
# 52:	learn: 2.5630299	total: 292ms	remaining: 5.21s
# 53:	learn: 2.5628270	total: 296ms	remaining: 5.18s
# 54:	learn: 2.5627986	total: 300ms	remaining: 5.15s
# 55:	learn: 2.5627010	total: 303ms	remaining: 5.11s
# 56:	learn: 2.5626208	total: 307ms	remaining: 5.08s
# 57:	learn: 2.5624475	total: 311ms	remaining: 5.05s
# 58:	learn: 2.5624117	total: 315ms	remaining: 5.02s
# 59:	learn: 2.5623757	total: 318ms	remaining: 4.99s
# 60:	learn: 2.5623065	total: 322ms	remaining: 4.96s
# 61:	learn: 2.5621500	total: 326ms	remaining: 4.93s
# 62:	learn: 2.5620315	total: 329ms	remaining: 4.9s
# 63:	learn: 2.5618955	total: 333ms	remaining: 4.87s
# 64:	learn: 2.5617553	total: 337ms	remaining: 4.84s
# 65:	learn: 2.5615431	total: 340ms	remaining: 4.81s
# 66:	learn: 2.5614750	total: 344ms	remaining: 4.79s
# 67:	learn: 2.5614080	total: 347ms	remaining: 4.76s
# 68:	learn: 2.5612522	total: 351ms	remaining: 4.74s
# 69:	learn: 2.5611441	total: 355ms	remaining: 4.71s
# 70:	learn: 2.5610439	total: 358ms	remaining: 4.69s
# 71:	learn: 2.5609255	total: 362ms	remaining: 4.67s
# 72:	learn: 2.5608191	total: 366ms	remaining: 4.65s
# 73:	learn: 2.5606978	total: 369ms	remaining: 4.62s
# 74:	learn: 2.5604880	total: 373ms	remaining: 4.6s
# 75:	learn: 2.5603876	total: 377ms	remaining: 4.58s
# 76:	learn: 2.5601957	total: 380ms	remaining: 4.56s
# 77:	learn: 2.5600828	total: 384ms	remaining: 4.54s
# 78:	learn: 2.5600140	total: 388ms	remaining: 4.52s
# 79:	learn: 2.5598892	total: 392ms	remaining: 4.51s
# 80:	learn: 2.5597762	total: 396ms	remaining: 4.49s
# 81:	learn: 2.5596176	total: 402ms	remaining: 4.5s
# 82:	learn: 2.5595564	total: 408ms	remaining: 4.51s
# 83:	learn: 2.5594665	total: 414ms	remaining: 4.51s
# 84:	learn: 2.5593649	total: 419ms	remaining: 4.51s
# 85:	learn: 2.5592059	total: 424ms	remaining: 4.51s
# 86:	learn: 2.5591464	total: 429ms	remaining: 4.5s
# 87:	learn: 2.5590392	total: 432ms	remaining: 4.48s
# 88:	learn: 2.5589538	total: 436ms	remaining: 4.46s
# 89:	learn: 2.5588216	total: 440ms	remaining: 4.45s
# 90:	learn: 2.5587880	total: 443ms	remaining: 4.43s
# 91:	learn: 2.5587144	total: 447ms	remaining: 4.41s
# 92:	learn: 2.5585738	total: 451ms	remaining: 4.39s
# 93:	learn: 2.5583949	total: 455ms	remaining: 4.39s
# 94:	learn: 2.5582822	total: 459ms	remaining: 4.38s
# 95:	learn: 2.5581883	total: 463ms	remaining: 4.36s
# 96:	learn: 2.5580932	total: 467ms	remaining: 4.35s
# 97:	learn: 2.5579933	total: 471ms	remaining: 4.33s
# 98:	learn: 2.5578335	total: 475ms	remaining: 4.32s
# 99:	learn: 2.5577256	total: 479ms	remaining: 4.31s
# 100:	learn: 2.5576176	total: 482ms	remaining: 4.29s
# 101:	learn: 2.5575060	total: 486ms	remaining: 4.28s
# 102:	learn: 2.5574226	total: 490ms	remaining: 4.27s
# 103:	learn: 2.5573358	total: 494ms	remaining: 4.26s
# 104:	learn: 2.5572206	total: 498ms	remaining: 4.24s
# 105:	learn: 2.5570136	total: 502ms	remaining: 4.23s
# 106:	learn: 2.5567703	total: 505ms	remaining: 4.22s
# 107:	learn: 2.5566215	total: 509ms	remaining: 4.2s
# 108:	learn: 2.5565209	total: 513ms	remaining: 4.19s
# 109:	learn: 2.5563896	total: 517ms	remaining: 4.18s
# 110:	learn: 2.5562704	total: 521ms	remaining: 4.17s
# 111:	learn: 2.5561987	total: 524ms	remaining: 4.16s
# 112:	learn: 2.5561844	total: 528ms	remaining: 4.14s
# 113:	learn: 2.5560423	total: 532ms	remaining: 4.13s
# 114:	learn: 2.5558592	total: 535ms	remaining: 4.12s
# 115:	learn: 2.5557130	total: 539ms	remaining: 4.11s
# 116:	learn: 2.5556523	total: 543ms	remaining: 4.1s
# 117:	learn: 2.5555920	total: 547ms	remaining: 4.08s
# 118:	learn: 2.5554963	total: 550ms	remaining: 4.07s
# 119:	learn: 2.5554785	total: 554ms	remaining: 4.06s
# 120:	learn: 2.5554085	total: 558ms	remaining: 4.05s
# 121:	learn: 2.5552704	total: 561ms	remaining: 4.04s
# 122:	learn: 2.5550769	total: 565ms	remaining: 4.03s
# 123:	learn: 2.5549124	total: 569ms	remaining: 4.02s
# 124:	learn: 2.5548431	total: 573ms	remaining: 4.01s
# 125:	learn: 2.5547995	total: 579ms	remaining: 4.02s
# 126:	learn: 2.5544196	total: 586ms	remaining: 4.03s
# 127:	learn: 2.5543208	total: 591ms	remaining: 4.03s
# 128:	learn: 2.5541977	total: 595ms	remaining: 4.02s
# 129:	learn: 2.5541190	total: 599ms	remaining: 4.01s
# 130:	learn: 2.5540215	total: 602ms	remaining: 4s
# 131:	learn: 2.5539577	total: 606ms	remaining: 3.98s
# 132:	learn: 2.5538220	total: 610ms	remaining: 3.97s
# 133:	learn: 2.5536636	total: 613ms	remaining: 3.96s
# 134:	learn: 2.5535685	total: 618ms	remaining: 3.96s
# 135:	learn: 2.5534350	total: 621ms	remaining: 3.95s
# 136:	learn: 2.5533601	total: 625ms	remaining: 3.94s
# 137:	learn: 2.5532533	total: 629ms	remaining: 3.92s
# 138:	learn: 2.5531418	total: 632ms	remaining: 3.92s
# 139:	learn: 2.5530704	total: 636ms	remaining: 3.9s
# 140:	learn: 2.5529174	total: 639ms	remaining: 3.9s
# 141:	learn: 2.5526264	total: 643ms	remaining: 3.88s
# 142:	learn: 2.5525527	total: 647ms	remaining: 3.88s
# 143:	learn: 2.5522637	total: 650ms	remaining: 3.87s
# 144:	learn: 2.5522087	total: 656ms	remaining: 3.87s
# 145:	learn: 2.5520186	total: 659ms	remaining: 3.86s
# 146:	learn: 2.5519822	total: 663ms	remaining: 3.85s
# 147:	learn: 2.5518606	total: 667ms	remaining: 3.84s
# 148:	learn: 2.5517843	total: 670ms	remaining: 3.83s
# 149:	learn: 2.5516040	total: 674ms	remaining: 3.82s
# 150:	learn: 2.5514196	total: 678ms	remaining: 3.81s
# 151:	learn: 2.5512723	total: 681ms	remaining: 3.8s
# 152:	learn: 2.5510522	total: 685ms	remaining: 3.79s
# 153:	learn: 2.5509742	total: 688ms	remaining: 3.78s
# 154:	learn: 2.5507824	total: 693ms	remaining: 3.77s
# 155:	learn: 2.5507485	total: 696ms	remaining: 3.77s
# 156:	learn: 2.5505754	total: 699ms	remaining: 3.75s
# 157:	learn: 2.5504677	total: 703ms	remaining: 3.75s
# 158:	learn: 2.5502388	total: 707ms	remaining: 3.74s
# 159:	learn: 2.5500405	total: 711ms	remaining: 3.73s
# 160:	learn: 2.5500088	total: 714ms	remaining: 3.72s
# 161:	learn: 2.5497272	total: 718ms	remaining: 3.71s
# 162:	learn: 2.5495335	total: 722ms	remaining: 3.71s
# 163:	learn: 2.5493833	total: 726ms	remaining: 3.7s
# 164:	learn: 2.5491944	total: 729ms	remaining: 3.69s
# 165:	learn: 2.5488925	total: 733ms	remaining: 3.68s
# 166:	learn: 2.5488114	total: 736ms	remaining: 3.67s
# 167:	learn: 2.5485763	total: 740ms	remaining: 3.67s
# 168:	learn: 2.5484189	total: 744ms	remaining: 3.66s
# 169:	learn: 2.5482248	total: 748ms	remaining: 3.65s
# 170:	learn: 2.5480541	total: 751ms	remaining: 3.64s
# 171:	learn: 2.5477455	total: 755ms	remaining: 3.63s
# 172:	learn: 2.5477243	total: 759ms	remaining: 3.63s
# 173:	learn: 2.5473725	total: 762ms	remaining: 3.62s
# 174:	learn: 2.5471388	total: 766ms	remaining: 3.61s
# 175:	learn: 2.5469777	total: 770ms	remaining: 3.6s
# 176:	learn: 2.5469180	total: 773ms	remaining: 3.6s
# 177:	learn: 2.5467545	total: 777ms	remaining: 3.59s
# 178:	learn: 2.5467186	total: 780ms	remaining: 3.58s
# 179:	learn: 2.5465194	total: 784ms	remaining: 3.57s
# 180:	learn: 2.5463083	total: 787ms	remaining: 3.56s
# 181:	learn: 2.5461594	total: 791ms	remaining: 3.55s
# 182:	learn: 2.5461465	total: 794ms	remaining: 3.54s
# 183:	learn: 2.5460489	total: 797ms	remaining: 3.54s
# 184:	learn: 2.5458770	total: 801ms	remaining: 3.53s
# 185:	learn: 2.5458002	total: 804ms	remaining: 3.52s
# 186:	learn: 2.5455885	total: 808ms	remaining: 3.51s
# 187:	learn: 2.5454784	total: 812ms	remaining: 3.51s
# 188:	learn: 2.5452356	total: 815ms	remaining: 3.5s
# 189:	learn: 2.5450819	total: 819ms	remaining: 3.49s
# 190:	learn: 2.5448936	total: 823ms	remaining: 3.48s
# 191:	learn: 2.5445598	total: 827ms	remaining: 3.48s
# 192:	learn: 2.5443618	total: 830ms	remaining: 3.47s
# 193:	learn: 2.5441571	total: 834ms	remaining: 3.46s
# 194:	learn: 2.5439604	total: 838ms	remaining: 3.46s
# 195:	learn: 2.5437922	total: 841ms	remaining: 3.45s
# 196:	learn: 2.5435705	total: 845ms	remaining: 3.44s
# 197:	learn: 2.5434035	total: 848ms	remaining: 3.44s
# 198:	learn: 2.5432594	total: 853ms	remaining: 3.43s
# 199:	learn: 2.5432512	total: 856ms	remaining: 3.42s
# 200:	learn: 2.5430671	total: 860ms	remaining: 3.42s
# 201:	learn: 2.5429178	total: 863ms	remaining: 3.41s
# 202:	learn: 2.5427520	total: 867ms	remaining: 3.4s
# 203:	learn: 2.5426119	total: 871ms	remaining: 3.4s
# 204:	learn: 2.5424589	total: 874ms	remaining: 3.39s
# 205:	learn: 2.5423376	total: 878ms	remaining: 3.38s
# 206:	learn: 2.5421497	total: 882ms	remaining: 3.38s
# 207:	learn: 2.5419601	total: 887ms	remaining: 3.38s
# 208:	learn: 2.5417432	total: 894ms	remaining: 3.38s
# 209:	learn: 2.5416077	total: 899ms	remaining: 3.38s
# 210:	learn: 2.5414866	total: 906ms	remaining: 3.39s
# 211:	learn: 2.5413112	total: 912ms	remaining: 3.39s
# 212:	learn: 2.5411000	total: 919ms	remaining: 3.4s
# 213:	learn: 2.5410196	total: 923ms	remaining: 3.39s
# 214:	learn: 2.5408981	total: 926ms	remaining: 3.38s
# 215:	learn: 2.5407908	total: 930ms	remaining: 3.38s
# 216:	learn: 2.5406570	total: 934ms	remaining: 3.37s
# 217:	learn: 2.5405672	total: 937ms	remaining: 3.36s
# 218:	learn: 2.5404263	total: 945ms	remaining: 3.37s
# 219:	learn: 2.5403504	total: 950ms	remaining: 3.37s
# 220:	learn: 2.5403166	total: 953ms	remaining: 3.36s
# 221:	learn: 2.5400565	total: 957ms	remaining: 3.35s
# 222:	learn: 2.5398760	total: 961ms	remaining: 3.35s
# 223:	learn: 2.5398471	total: 964ms	remaining: 3.34s
# 224:	learn: 2.5397032	total: 968ms	remaining: 3.33s
# 225:	learn: 2.5393611	total: 972ms	remaining: 3.33s
# 226:	learn: 2.5392978	total: 976ms	remaining: 3.32s
# 227:	learn: 2.5392768	total: 980ms	remaining: 3.32s
# 228:	learn: 2.5392584	total: 987ms	remaining: 3.32s
# 229:	learn: 2.5390226	total: 991ms	remaining: 3.32s
# 230:	learn: 2.5389829	total: 995ms	remaining: 3.31s
# 231:	learn: 2.5389332	total: 999ms	remaining: 3.31s
# 232:	learn: 2.5388637	total: 1s	remaining: 3.3s
# 233:	learn: 2.5387970	total: 1.01s	remaining: 3.3s
# 234:	learn: 2.5386367	total: 1.01s	remaining: 3.29s
# 235:	learn: 2.5384998	total: 1.02s	remaining: 3.29s
# 236:	learn: 2.5384273	total: 1.02s	remaining: 3.29s
# 237:	learn: 2.5383070	total: 1.02s	remaining: 3.28s
# 238:	learn: 2.5381775	total: 1.03s	remaining: 3.28s
# 239:	learn: 2.5380629	total: 1.03s	remaining: 3.27s
# 240:	learn: 2.5379332	total: 1.04s	remaining: 3.27s
# 241:	learn: 2.5378376	total: 1.04s	remaining: 3.27s
# 242:	learn: 2.5376620	total: 1.05s	remaining: 3.26s
# 243:	learn: 2.5375169	total: 1.05s	remaining: 3.26s
# 244:	learn: 2.5374907	total: 1.06s	remaining: 3.26s
# 245:	learn: 2.5373996	total: 1.06s	remaining: 3.26s
# 246:	learn: 2.5371968	total: 1.07s	remaining: 3.25s
# 247:	learn: 2.5370183	total: 1.07s	remaining: 3.25s
# 248:	learn: 2.5368319	total: 1.08s	remaining: 3.25s
# 249:	learn: 2.5366470	total: 1.09s	remaining: 3.26s
# 250:	learn: 2.5365114	total: 1.09s	remaining: 3.26s
# 251:	learn: 2.5364083	total: 1.1s	remaining: 3.25s
# 252:	learn: 2.5363030	total: 1.1s	remaining: 3.25s
# 253:	learn: 2.5362786	total: 1.1s	remaining: 3.24s
# 254:	learn: 2.5361413	total: 1.11s	remaining: 3.25s
# 255:	learn: 2.5359816	total: 1.12s	remaining: 3.27s
# 256:	learn: 2.5358222	total: 1.13s	remaining: 3.28s
# 257:	learn: 2.5356699	total: 1.14s	remaining: 3.28s
# 258:	learn: 2.5355402	total: 1.14s	remaining: 3.27s
# 259:	learn: 2.5353483	total: 1.15s	remaining: 3.27s
# 260:	learn: 2.5353408	total: 1.15s	remaining: 3.27s
# 261:	learn: 2.5351687	total: 1.16s	remaining: 3.26s
# 262:	learn: 2.5350152	total: 1.16s	remaining: 3.26s
# 263:	learn: 2.5347862	total: 1.17s	remaining: 3.25s
# 264:	learn: 2.5347568	total: 1.17s	remaining: 3.25s
# 265:	learn: 2.5346930	total: 1.17s	remaining: 3.24s
# 266:	learn: 2.5346460	total: 1.18s	remaining: 3.24s
# 267:	learn: 2.5345289	total: 1.18s	remaining: 3.23s
# 268:	learn: 2.5344506	total: 1.19s	remaining: 3.23s
# 269:	learn: 2.5342279	total: 1.19s	remaining: 3.23s
# 270:	learn: 2.5340671	total: 1.2s	remaining: 3.23s
# 271:	learn: 2.5340100	total: 1.21s	remaining: 3.23s
# 272:	learn: 2.5339344	total: 1.21s	remaining: 3.22s
# 273:	learn: 2.5338285	total: 1.21s	remaining: 3.22s
# 274:	learn: 2.5337335	total: 1.22s	remaining: 3.21s
# 275:	learn: 2.5336457	total: 1.22s	remaining: 3.21s
# 276:	learn: 2.5335797	total: 1.23s	remaining: 3.2s
# 277:	learn: 2.5335606	total: 1.24s	remaining: 3.21s
# 278:	learn: 2.5334275	total: 1.24s	remaining: 3.21s
# 279:	learn: 2.5332579	total: 1.25s	remaining: 3.21s
# 280:	learn: 2.5331938	total: 1.26s	remaining: 3.22s
# 281:	learn: 2.5330060	total: 1.26s	remaining: 3.22s
# 282:	learn: 2.5327916	total: 1.27s	remaining: 3.22s
# 283:	learn: 2.5326909	total: 1.28s	remaining: 3.23s
# 284:	learn: 2.5326758	total: 1.28s	remaining: 3.23s
# 285:	learn: 2.5325682	total: 1.29s	remaining: 3.23s
# 286:	learn: 2.5324045	total: 1.3s	remaining: 3.23s
# 287:	learn: 2.5323491	total: 1.31s	remaining: 3.23s
# 288:	learn: 2.5321811	total: 1.31s	remaining: 3.23s
# 289:	learn: 2.5320647	total: 1.32s	remaining: 3.24s
# 290:	learn: 2.5319795	total: 1.33s	remaining: 3.24s
# 291:	learn: 2.5318734	total: 1.33s	remaining: 3.24s
# 292:	learn: 2.5316668	total: 1.34s	remaining: 3.24s
# 293:	learn: 2.5314795	total: 1.35s	remaining: 3.25s
# 294:	learn: 2.5314501	total: 1.36s	remaining: 3.24s
# 295:	learn: 2.5313047	total: 1.37s	remaining: 3.25s
# 296:	learn: 2.5310250	total: 1.37s	remaining: 3.25s
# 297:	learn: 2.5309484	total: 1.38s	remaining: 3.25s
# 298:	learn: 2.5309240	total: 1.38s	remaining: 3.24s
# 299:	learn: 2.5308213	total: 1.39s	remaining: 3.24s
# 300:	learn: 2.5307171	total: 1.39s	remaining: 3.24s
# 301:	learn: 2.5306205	total: 1.4s	remaining: 3.25s
# 302:	learn: 2.5304459	total: 1.42s	remaining: 3.27s
# 303:	learn: 2.5304293	total: 1.43s	remaining: 3.28s
# 304:	learn: 2.5302502	total: 1.44s	remaining: 3.29s
# 305:	learn: 2.5301027	total: 1.45s	remaining: 3.29s
# 306:	learn: 2.5299536	total: 1.45s	remaining: 3.28s
# 307:	learn: 2.5299073	total: 1.46s	remaining: 3.28s
# 308:	learn: 2.5297666	total: 1.47s	remaining: 3.28s
# 309:	learn: 2.5296310	total: 1.47s	remaining: 3.27s
# 310:	learn: 2.5295087	total: 1.47s	remaining: 3.27s
# 311:	learn: 2.5294612	total: 1.48s	remaining: 3.26s
# 312:	learn: 2.5294457	total: 1.48s	remaining: 3.25s
# 313:	learn: 2.5292994	total: 1.49s	remaining: 3.25s
# 314:	learn: 2.5291769	total: 1.51s	remaining: 3.28s
# 315:	learn: 2.5291607	total: 1.52s	remaining: 3.29s
# 316:	learn: 2.5289826	total: 1.53s	remaining: 3.29s
# 317:	learn: 2.5288105	total: 1.53s	remaining: 3.29s
# 318:	learn: 2.5286379	total: 1.56s	remaining: 3.33s
# 319:	learn: 2.5285219	total: 1.57s	remaining: 3.34s
# 320:	learn: 2.5284271	total: 1.58s	remaining: 3.35s
# 321:	learn: 2.5283459	total: 1.59s	remaining: 3.35s
# 322:	learn: 2.5282056	total: 1.6s	remaining: 3.35s
# 323:	learn: 2.5281891	total: 1.61s	remaining: 3.36s
# 324:	learn: 2.5279982	total: 1.62s	remaining: 3.37s
# 325:	learn: 2.5279266	total: 1.63s	remaining: 3.36s
# 326:	learn: 2.5277917	total: 1.63s	remaining: 3.36s
# 327:	learn: 2.5277402	total: 1.64s	remaining: 3.36s
# 328:	learn: 2.5276987	total: 1.65s	remaining: 3.36s
# 329:	learn: 2.5275667	total: 1.66s	remaining: 3.36s
# 330:	learn: 2.5273832	total: 1.66s	remaining: 3.36s
# 331:	learn: 2.5272662	total: 1.67s	remaining: 3.37s
# 332:	learn: 2.5271442	total: 1.68s	remaining: 3.37s
# 333:	learn: 2.5269953	total: 1.69s	remaining: 3.37s
# 334:	learn: 2.5268851	total: 1.7s	remaining: 3.37s
# 335:	learn: 2.5268697	total: 1.7s	remaining: 3.36s
# 336:	learn: 2.5267025	total: 1.7s	remaining: 3.35s
# 337:	learn: 2.5266045	total: 1.71s	remaining: 3.35s
# 338:	learn: 2.5265415	total: 1.71s	remaining: 3.34s
# 339:	learn: 2.5263949	total: 1.72s	remaining: 3.33s
# 340:	learn: 2.5262687	total: 1.72s	remaining: 3.33s
# 341:	learn: 2.5260829	total: 1.73s	remaining: 3.32s
# 342:	learn: 2.5260157	total: 1.73s	remaining: 3.31s
# 343:	learn: 2.5259828	total: 1.73s	remaining: 3.31s
# 344:	learn: 2.5259246	total: 1.75s	remaining: 3.32s
# 345:	learn: 2.5257781	total: 1.76s	remaining: 3.32s
# 346:	learn: 2.5257171	total: 1.76s	remaining: 3.32s
# 347:	learn: 2.5255932	total: 1.77s	remaining: 3.31s
# 348:	learn: 2.5254391	total: 1.78s	remaining: 3.31s
# 349:	learn: 2.5253322	total: 1.78s	remaining: 3.31s
# 350:	learn: 2.5251628	total: 1.79s	remaining: 3.31s
# 351:	learn: 2.5250354	total: 1.81s	remaining: 3.32s
# 352:	learn: 2.5249973	total: 1.81s	remaining: 3.32s
# 353:	learn: 2.5249000	total: 1.81s	remaining: 3.31s
# 354:	learn: 2.5248614	total: 1.82s	remaining: 3.31s
# 355:	learn: 2.5247446	total: 1.82s	remaining: 3.3s
# 356:	learn: 2.5246066	total: 1.83s	remaining: 3.29s
# 357:	learn: 2.5245837	total: 1.83s	remaining: 3.29s
# 358:	learn: 2.5243992	total: 1.84s	remaining: 3.28s
# 359:	learn: 2.5243760	total: 1.84s	remaining: 3.28s
# 360:	learn: 2.5242175	total: 1.85s	remaining: 3.27s
# 361:	learn: 2.5240566	total: 1.85s	remaining: 3.26s
# 362:	learn: 2.5239745	total: 1.86s	remaining: 3.26s
# 363:	learn: 2.5239620	total: 1.86s	remaining: 3.25s
# 364:	learn: 2.5237982	total: 1.88s	remaining: 3.27s
# 365:	learn: 2.5237204	total: 1.88s	remaining: 3.27s
# 366:	learn: 2.5235807	total: 1.89s	remaining: 3.26s
# 367:	learn: 2.5234462	total: 1.9s	remaining: 3.27s
# 368:	learn: 2.5234125	total: 1.92s	remaining: 3.28s
# 369:	learn: 2.5234007	total: 1.93s	remaining: 3.28s
# 370:	learn: 2.5231815	total: 1.94s	remaining: 3.29s
# 371:	learn: 2.5231664	total: 1.95s	remaining: 3.29s
# 372:	learn: 2.5230570	total: 1.96s	remaining: 3.29s
# 373:	learn: 2.5228948	total: 1.97s	remaining: 3.29s
# 374:	learn: 2.5228057	total: 1.98s	remaining: 3.3s
# 375:	learn: 2.5226380	total: 2s	remaining: 3.33s
# 376:	learn: 2.5226268	total: 2.01s	remaining: 3.33s
# 377:	learn: 2.5226138	total: 2.02s	remaining: 3.33s
# 378:	learn: 2.5224255	total: 2.03s	remaining: 3.33s
# 379:	learn: 2.5222505	total: 2.05s	remaining: 3.35s
# 380:	learn: 2.5221218	total: 2.06s	remaining: 3.35s
# 381:	learn: 2.5219657	total: 2.07s	remaining: 3.35s
# 382:	learn: 2.5218934	total: 2.09s	remaining: 3.36s
# 383:	learn: 2.5217860	total: 2.1s	remaining: 3.37s
# 384:	learn: 2.5216662	total: 2.1s	remaining: 3.36s
# 385:	learn: 2.5215589	total: 2.11s	remaining: 3.36s
# 386:	learn: 2.5214807	total: 2.11s	remaining: 3.35s
# 387:	learn: 2.5212776	total: 2.12s	remaining: 3.34s
# 388:	learn: 2.5211601	total: 2.13s	remaining: 3.34s
# 389:	learn: 2.5210393	total: 2.14s	remaining: 3.35s
# 390:	learn: 2.5209214	total: 2.15s	remaining: 3.35s
# 391:	learn: 2.5209005	total: 2.15s	remaining: 3.34s
# 392:	learn: 2.5207881	total: 2.16s	remaining: 3.33s
# 393:	learn: 2.5206411	total: 2.16s	remaining: 3.33s
# 394:	learn: 2.5206307	total: 2.19s	remaining: 3.35s
# 395:	learn: 2.5205031	total: 2.19s	remaining: 3.35s
# 396:	learn: 2.5202759	total: 2.2s	remaining: 3.35s
# 397:	learn: 2.5201695	total: 2.21s	remaining: 3.35s
# 398:	learn: 2.5199964	total: 2.22s	remaining: 3.35s
# 399:	learn: 2.5199751	total: 2.23s	remaining: 3.35s
# 400:	learn: 2.5198832	total: 2.24s	remaining: 3.34s
# 401:	learn: 2.5197171	total: 2.25s	remaining: 3.34s
# 402:	learn: 2.5196906	total: 2.26s	remaining: 3.34s
# 403:	learn: 2.5195474	total: 2.27s	remaining: 3.34s
# 404:	learn: 2.5194159	total: 2.27s	remaining: 3.34s
# 405:	learn: 2.5192876	total: 2.29s	remaining: 3.35s
# 406:	learn: 2.5191703	total: 2.3s	remaining: 3.35s
# 407:	learn: 2.5189554	total: 2.3s	remaining: 3.34s
# 408:	learn: 2.5189044	total: 2.31s	remaining: 3.34s
# 409:	learn: 2.5188142	total: 2.32s	remaining: 3.33s
# 410:	learn: 2.5186802	total: 2.32s	remaining: 3.33s
# 411:	learn: 2.5184332	total: 2.33s	remaining: 3.33s
# 412:	learn: 2.5182564	total: 2.34s	remaining: 3.32s
# 413:	learn: 2.5182324	total: 2.34s	remaining: 3.32s
# 414:	learn: 2.5182208	total: 2.36s	remaining: 3.32s
# 415:	learn: 2.5180495	total: 2.37s	remaining: 3.32s
# 416:	learn: 2.5179848	total: 2.37s	remaining: 3.32s
# 417:	learn: 2.5179248	total: 2.38s	remaining: 3.31s
# 418:	learn: 2.5178870	total: 2.38s	remaining: 3.31s
# 419:	learn: 2.5177790	total: 2.39s	remaining: 3.3s
# 420:	learn: 2.5176841	total: 2.4s	remaining: 3.3s
# 421:	learn: 2.5176199	total: 2.4s	remaining: 3.29s
# 422:	learn: 2.5174821	total: 2.4s	remaining: 3.28s
# 423:	learn: 2.5173086	total: 2.41s	remaining: 3.27s
# 424:	learn: 2.5172982	total: 2.42s	remaining: 3.27s
# 425:	learn: 2.5172643	total: 2.42s	remaining: 3.26s
# 426:	learn: 2.5172530	total: 2.43s	remaining: 3.25s
# 427:	learn: 2.5171550	total: 2.43s	remaining: 3.25s
# 428:	learn: 2.5170849	total: 2.43s	remaining: 3.24s
# 429:	learn: 2.5169949	total: 2.44s	remaining: 3.23s
# 430:	learn: 2.5168518	total: 2.44s	remaining: 3.23s
# 431:	learn: 2.5167398	total: 2.45s	remaining: 3.22s
# 432:	learn: 2.5166517	total: 2.45s	remaining: 3.21s
# 433:	learn: 2.5165369	total: 2.46s	remaining: 3.2s
# 434:	learn: 2.5164665	total: 2.46s	remaining: 3.2s
# 435:	learn: 2.5163823	total: 2.46s	remaining: 3.19s
# 436:	learn: 2.5161999	total: 2.47s	remaining: 3.18s
# 437:	learn: 2.5161056	total: 2.48s	remaining: 3.18s
# 438:	learn: 2.5159572	total: 2.48s	remaining: 3.17s
# 439:	learn: 2.5159108	total: 2.5s	remaining: 3.18s
# 440:	learn: 2.5158010	total: 2.5s	remaining: 3.17s
# 441:	learn: 2.5157561	total: 2.51s	remaining: 3.17s
# 442:	learn: 2.5156275	total: 2.52s	remaining: 3.16s
# 443:	learn: 2.5155689	total: 2.52s	remaining: 3.16s
# 444:	learn: 2.5155507	total: 2.53s	remaining: 3.16s
# 445:	learn: 2.5155414	total: 2.55s	remaining: 3.16s
# 446:	learn: 2.5154057	total: 2.55s	remaining: 3.16s
# 447:	learn: 2.5153096	total: 2.57s	remaining: 3.16s
# 448:	learn: 2.5152384	total: 2.58s	remaining: 3.17s
# 449:	learn: 2.5152126	total: 2.59s	remaining: 3.17s
# 450:	learn: 2.5151320	total: 2.6s	remaining: 3.16s
# 451:	learn: 2.5150716	total: 2.61s	remaining: 3.16s
# 452:	learn: 2.5149188	total: 2.62s	remaining: 3.16s
# 453:	learn: 2.5147655	total: 2.63s	remaining: 3.16s
# 454:	learn: 2.5146515	total: 2.64s	remaining: 3.16s
# 455:	learn: 2.5146349	total: 2.64s	remaining: 3.15s
# 456:	learn: 2.5145745	total: 2.66s	remaining: 3.16s
# 457:	learn: 2.5145236	total: 2.67s	remaining: 3.16s
# 458:	learn: 2.5144500	total: 2.67s	remaining: 3.15s
# 459:	learn: 2.5143461	total: 2.67s	remaining: 3.14s
# 460:	learn: 2.5142457	total: 2.68s	remaining: 3.13s
# 461:	learn: 2.5142257	total: 2.69s	remaining: 3.13s
# 462:	learn: 2.5141224	total: 2.7s	remaining: 3.13s
# 463:	learn: 2.5140153	total: 2.7s	remaining: 3.12s
# 464:	learn: 2.5138691	total: 2.71s	remaining: 3.12s
# 465:	learn: 2.5137703	total: 2.72s	remaining: 3.11s
# 466:	learn: 2.5136956	total: 2.72s	remaining: 3.11s
# 467:	learn: 2.5136865	total: 2.73s	remaining: 3.1s
# 468:	learn: 2.5136710	total: 2.74s	remaining: 3.1s
# 469:	learn: 2.5135684	total: 2.75s	remaining: 3.1s
# 470:	learn: 2.5134517	total: 2.75s	remaining: 3.09s
# 471:	learn: 2.5133667	total: 2.75s	remaining: 3.08s
# 472:	learn: 2.5132394	total: 2.76s	remaining: 3.08s
# 473:	learn: 2.5132300	total: 2.77s	remaining: 3.07s
# 474:	learn: 2.5130685	total: 2.77s	remaining: 3.06s
# 475:	learn: 2.5128453	total: 2.77s	remaining: 3.05s
# 476:	learn: 2.5126684	total: 2.78s	remaining: 3.05s
# 477:	learn: 2.5126311	total: 2.79s	remaining: 3.05s
# 478:	learn: 2.5124379	total: 2.81s	remaining: 3.05s
# 479:	learn: 2.5124336	total: 2.82s	remaining: 3.05s
# 480:	learn: 2.5122892	total: 2.83s	remaining: 3.05s
# 481:	learn: 2.5121947	total: 2.84s	remaining: 3.05s
# 482:	learn: 2.5121087	total: 2.85s	remaining: 3.05s
# 483:	learn: 2.5120120	total: 2.85s	remaining: 3.04s
# 484:	learn: 2.5117793	total: 2.86s	remaining: 3.04s
# 485:	learn: 2.5116632	total: 2.87s	remaining: 3.04s
# 486:	learn: 2.5116526	total: 2.87s	remaining: 3.03s
# 487:	learn: 2.5115263	total: 2.88s	remaining: 3.02s
# 488:	learn: 2.5114703	total: 2.88s	remaining: 3.02s
# 489:	learn: 2.5113470	total: 2.89s	remaining: 3.01s
# 490:	learn: 2.5111969	total: 2.9s	remaining: 3.01s
# 491:	learn: 2.5111811	total: 2.91s	remaining: 3s
# 492:	learn: 2.5110817	total: 2.92s	remaining: 3.01s
# 493:	learn: 2.5110332	total: 2.93s	remaining: 3.01s
# 494:	learn: 2.5110162	total: 2.94s	remaining: 3s
# 495:	learn: 2.5109341	total: 2.95s	remaining: 3s
# 496:	learn: 2.5108017	total: 2.96s	remaining: 3s
# 497:	learn: 2.5106361	total: 2.97s	remaining: 3s
# 498:	learn: 2.5105581	total: 2.98s	remaining: 2.99s
# 499:	learn: 2.5104169	total: 2.98s	remaining: 2.98s
# 500:	learn: 2.5102771	total: 2.99s	remaining: 2.98s
# 501:	learn: 2.5101187	total: 3s	remaining: 2.97s
# 502:	learn: 2.5099965	total: 3s	remaining: 2.96s
# 503:	learn: 2.5097851	total: 3.01s	remaining: 2.96s
# 504:	learn: 2.5096366	total: 3.01s	remaining: 2.95s
# 505:	learn: 2.5095816	total: 3.04s	remaining: 2.97s
# 506:	learn: 2.5093904	total: 3.05s	remaining: 2.96s
# 507:	learn: 2.5093097	total: 3.05s	remaining: 2.96s
# 508:	learn: 2.5091242	total: 3.08s	remaining: 2.97s
# 509:	learn: 2.5090010	total: 3.09s	remaining: 2.97s
# 510:	learn: 2.5089156	total: 3.1s	remaining: 2.97s
# 511:	learn: 2.5088573	total: 3.1s	remaining: 2.96s
# 512:	learn: 2.5087630	total: 3.11s	remaining: 2.96s
# 513:	learn: 2.5086118	total: 3.12s	remaining: 2.95s
# 514:	learn: 2.5085121	total: 3.12s	remaining: 2.94s
# 515:	learn: 2.5084068	total: 3.13s	remaining: 2.94s
# 516:	learn: 2.5083060	total: 3.13s	remaining: 2.93s
# 517:	learn: 2.5082649	total: 3.15s	remaining: 2.93s
# 518:	learn: 2.5082110	total: 3.16s	remaining: 2.92s
# 519:	learn: 2.5081266	total: 3.16s	remaining: 2.92s
# 520:	learn: 2.5079915	total: 3.17s	remaining: 2.91s
# 521:	learn: 2.5079291	total: 3.17s	remaining: 2.9s
# 522:	learn: 2.5078220	total: 3.18s	remaining: 2.9s
# 523:	learn: 2.5076906	total: 3.18s	remaining: 2.89s
# 524:	learn: 2.5075238	total: 3.19s	remaining: 2.88s
# 525:	learn: 2.5073510	total: 3.19s	remaining: 2.88s
# 526:	learn: 2.5072418	total: 3.2s	remaining: 2.87s
# 527:	learn: 2.5071494	total: 3.21s	remaining: 2.87s
# 528:	learn: 2.5070429	total: 3.21s	remaining: 2.86s
# 529:	learn: 2.5069065	total: 3.23s	remaining: 2.87s
# 530:	learn: 2.5067905	total: 3.24s	remaining: 2.86s
# 531:	learn: 2.5067830	total: 3.24s	remaining: 2.85s
# 532:	learn: 2.5066654	total: 3.25s	remaining: 2.85s
# 533:	learn: 2.5065847	total: 3.27s	remaining: 2.85s
# 534:	learn: 2.5064787	total: 3.28s	remaining: 2.85s
# 535:	learn: 2.5064005	total: 3.29s	remaining: 2.85s
# 536:	learn: 2.5063445	total: 3.3s	remaining: 2.84s
# 537:	learn: 2.5062066	total: 3.31s	remaining: 2.84s
# 538:	learn: 2.5060663	total: 3.33s	remaining: 2.85s
# 539:	learn: 2.5059625	total: 3.34s	remaining: 2.84s
# 540:	learn: 2.5059556	total: 3.35s	remaining: 2.84s
# 541:	learn: 2.5059471	total: 3.36s	remaining: 2.84s
# 542:	learn: 2.5058348	total: 3.36s	remaining: 2.83s
# 543:	learn: 2.5057185	total: 3.37s	remaining: 2.83s
# 544:	learn: 2.5057144	total: 3.38s	remaining: 2.82s
# 545:	learn: 2.5056211	total: 3.39s	remaining: 2.82s
# 546:	learn: 2.5055074	total: 3.4s	remaining: 2.82s
# 547:	learn: 2.5053947	total: 3.42s	remaining: 2.82s
# 548:	learn: 2.5052719	total: 3.42s	remaining: 2.81s
# 549:	learn: 2.5051709	total: 3.43s	remaining: 2.81s
# 550:	learn: 2.5050827	total: 3.43s	remaining: 2.8s
# 551:	learn: 2.5050752	total: 3.44s	remaining: 2.79s
# 552:	learn: 2.5050545	total: 3.44s	remaining: 2.78s
# 553:	learn: 2.5048838	total: 3.45s	remaining: 2.77s
# 554:	learn: 2.5047148	total: 3.45s	remaining: 2.77s
# 555:	learn: 2.5046285	total: 3.46s	remaining: 2.76s
# 556:	learn: 2.5045364	total: 3.46s	remaining: 2.75s
# 557:	learn: 2.5045312	total: 3.47s	remaining: 2.75s
# 558:	learn: 2.5043857	total: 3.48s	remaining: 2.74s
# 559:	learn: 2.5042706	total: 3.48s	remaining: 2.73s
# 560:	learn: 2.5042368	total: 3.48s	remaining: 2.73s
# 561:	learn: 2.5041471	total: 3.49s	remaining: 2.72s
# 562:	learn: 2.5040550	total: 3.49s	remaining: 2.71s
# 563:	learn: 2.5039282	total: 3.5s	remaining: 2.7s
# 564:	learn: 2.5038115	total: 3.5s	remaining: 2.7s
# 565:	learn: 2.5036947	total: 3.52s	remaining: 2.69s
# 566:	learn: 2.5036110	total: 3.52s	remaining: 2.69s
# 567:	learn: 2.5035252	total: 3.52s	remaining: 2.68s
# 568:	learn: 2.5033476	total: 3.54s	remaining: 2.68s
# 569:	learn: 2.5032547	total: 3.54s	remaining: 2.67s
# 570:	learn: 2.5030645	total: 3.55s	remaining: 2.67s
# 571:	learn: 2.5029976	total: 3.56s	remaining: 2.66s
# 572:	learn: 2.5029094	total: 3.56s	remaining: 2.65s
# 573:	learn: 2.5028213	total: 3.56s	remaining: 2.64s
# 574:	learn: 2.5027300	total: 3.57s	remaining: 2.64s
# 575:	learn: 2.5026996	total: 3.58s	remaining: 2.63s
# 576:	learn: 2.5025934	total: 3.58s	remaining: 2.62s
# 577:	learn: 2.5024550	total: 3.58s	remaining: 2.62s
# 578:	learn: 2.5023767	total: 3.59s	remaining: 2.61s
# 579:	learn: 2.5022861	total: 3.59s	remaining: 2.6s
# 580:	learn: 2.5022125	total: 3.6s	remaining: 2.59s
# 581:	learn: 2.5021837	total: 3.6s	remaining: 2.59s
# 582:	learn: 2.5020525	total: 3.6s	remaining: 2.58s
# 583:	learn: 2.5020260	total: 3.61s	remaining: 2.57s
# 584:	learn: 2.5019173	total: 3.61s	remaining: 2.56s
# 585:	learn: 2.5018091	total: 3.62s	remaining: 2.55s
# 586:	learn: 2.5018042	total: 3.62s	remaining: 2.55s
# 587:	learn: 2.5017896	total: 3.62s	remaining: 2.54s
# 588:	learn: 2.5017208	total: 3.63s	remaining: 2.53s
# 589:	learn: 2.5016307	total: 3.63s	remaining: 2.52s
# 590:	learn: 2.5015514	total: 3.64s	remaining: 2.52s
# 591:	learn: 2.5015349	total: 3.64s	remaining: 2.51s
# 592:	learn: 2.5014784	total: 3.65s	remaining: 2.5s
# 593:	learn: 2.5013441	total: 3.65s	remaining: 2.49s
# 594:	learn: 2.5012855	total: 3.65s	remaining: 2.49s
# 595:	learn: 2.5012427	total: 3.66s	remaining: 2.48s
# 596:	learn: 2.5011565	total: 3.66s	remaining: 2.47s
# 597:	learn: 2.5010457	total: 3.66s	remaining: 2.46s
# 598:	learn: 2.5009127	total: 3.67s	remaining: 2.46s
# 599:	learn: 2.5008578	total: 3.67s	remaining: 2.45s
# 600:	learn: 2.5007778	total: 3.68s	remaining: 2.44s
# 601:	learn: 2.5007098	total: 3.68s	remaining: 2.43s
# 602:	learn: 2.5005973	total: 3.69s	remaining: 2.43s
# 603:	learn: 2.5004917	total: 3.69s	remaining: 2.42s
# 604:	learn: 2.5003869	total: 3.69s	remaining: 2.41s
# 605:	learn: 2.5003186	total: 3.7s	remaining: 2.4s
# 606:	learn: 2.5001923	total: 3.7s	remaining: 2.4s
# 607:	learn: 2.5000534	total: 3.71s	remaining: 2.39s
# 608:	learn: 2.4999717	total: 3.71s	remaining: 2.38s
# 609:	learn: 2.4999145	total: 3.71s	remaining: 2.38s
# 610:	learn: 2.4998061	total: 3.72s	remaining: 2.37s
# 611:	learn: 2.4996422	total: 3.72s	remaining: 2.36s
# 612:	learn: 2.4995055	total: 3.73s	remaining: 2.35s
# 613:	learn: 2.4994061	total: 3.73s	remaining: 2.35s
# 614:	learn: 2.4991962	total: 3.74s	remaining: 2.34s
# 615:	learn: 2.4990903	total: 3.74s	remaining: 2.33s
# 616:	learn: 2.4990385	total: 3.75s	remaining: 2.33s
# 617:	learn: 2.4989588	total: 3.75s	remaining: 2.32s
# 618:	learn: 2.4989424	total: 3.75s	remaining: 2.31s
# 619:	learn: 2.4988555	total: 3.76s	remaining: 2.3s
# 620:	learn: 2.4987007	total: 3.76s	remaining: 2.29s
# 621:	learn: 2.4986284	total: 3.77s	remaining: 2.29s
# 622:	learn: 2.4985555	total: 3.77s	remaining: 2.28s
# 623:	learn: 2.4984584	total: 3.77s	remaining: 2.27s
# 624:	learn: 2.4984202	total: 3.78s	remaining: 2.27s
# 625:	learn: 2.4983794	total: 3.78s	remaining: 2.26s
# 626:	learn: 2.4982690	total: 3.79s	remaining: 2.25s
# 627:	learn: 2.4981067	total: 3.79s	remaining: 2.25s
# 628:	learn: 2.4979820	total: 3.79s	remaining: 2.24s
# 629:	learn: 2.4978326	total: 3.8s	remaining: 2.23s
# 630:	learn: 2.4977186	total: 3.8s	remaining: 2.22s
# 631:	learn: 2.4976197	total: 3.81s	remaining: 2.22s
# 632:	learn: 2.4975520	total: 3.81s	remaining: 2.21s
# 633:	learn: 2.4974950	total: 3.82s	remaining: 2.2s
# 634:	learn: 2.4973873	total: 3.82s	remaining: 2.2s
# 635:	learn: 2.4973581	total: 3.83s	remaining: 2.19s
# 636:	learn: 2.4972973	total: 3.83s	remaining: 2.18s
# 637:	learn: 2.4972825	total: 3.83s	remaining: 2.18s
# 638:	learn: 2.4971867	total: 3.84s	remaining: 2.17s
# 639:	learn: 2.4971812	total: 3.84s	remaining: 2.16s
# 640:	learn: 2.4971202	total: 3.85s	remaining: 2.15s
# 641:	learn: 2.4970133	total: 3.85s	remaining: 2.15s
# 642:	learn: 2.4968950	total: 3.86s	remaining: 2.14s
# 643:	learn: 2.4968804	total: 3.86s	remaining: 2.13s
# 644:	learn: 2.4967387	total: 3.86s	remaining: 2.13s
# 645:	learn: 2.4966629	total: 3.87s	remaining: 2.12s
# 646:	learn: 2.4965394	total: 3.87s	remaining: 2.11s
# 647:	learn: 2.4965337	total: 3.88s	remaining: 2.1s
# 648:	learn: 2.4964842	total: 3.88s	remaining: 2.1s
# 649:	learn: 2.4964400	total: 3.88s	remaining: 2.09s
# 650:	learn: 2.4963690	total: 3.89s	remaining: 2.08s
# 651:	learn: 2.4962712	total: 3.89s	remaining: 2.08s
# 652:	learn: 2.4961527	total: 3.9s	remaining: 2.07s
# 653:	learn: 2.4960470	total: 3.9s	remaining: 2.06s
# 654:	learn: 2.4959326	total: 3.9s	remaining: 2.06s
# 655:	learn: 2.4959218	total: 3.91s	remaining: 2.05s
# 656:	learn: 2.4958497	total: 3.91s	remaining: 2.04s
# 657:	learn: 2.4957609	total: 3.92s	remaining: 2.04s
# 658:	learn: 2.4956469	total: 3.92s	remaining: 2.03s
# 659:	learn: 2.4955484	total: 3.92s	remaining: 2.02s
# 660:	learn: 2.4953333	total: 3.93s	remaining: 2.01s
# 661:	learn: 2.4952961	total: 3.93s	remaining: 2.01s
# 662:	learn: 2.4952076	total: 3.94s	remaining: 2s
# 663:	learn: 2.4951138	total: 3.94s	remaining: 2s
# 664:	learn: 2.4950025	total: 3.95s	remaining: 1.99s
# 665:	learn: 2.4948932	total: 3.96s	remaining: 1.98s
# 666:	learn: 2.4948801	total: 3.96s	remaining: 1.98s
# 667:	learn: 2.4948028	total: 3.96s	remaining: 1.97s
# 668:	learn: 2.4946897	total: 3.97s	remaining: 1.96s
# 669:	learn: 2.4946071	total: 3.97s	remaining: 1.96s
# 670:	learn: 2.4945908	total: 3.98s	remaining: 1.95s
# 671:	learn: 2.4944672	total: 3.98s	remaining: 1.95s
# 672:	learn: 2.4943805	total: 3.99s	remaining: 1.94s
# 673:	learn: 2.4942972	total: 4s	remaining: 1.93s
# 674:	learn: 2.4941694	total: 4s	remaining: 1.93s
# 675:	learn: 2.4941546	total: 4s	remaining: 1.92s
# 676:	learn: 2.4940963	total: 4.01s	remaining: 1.91s
# 677:	learn: 2.4939205	total: 4.01s	remaining: 1.91s
# 678:	learn: 2.4938695	total: 4.03s	remaining: 1.9s
# 679:	learn: 2.4937982	total: 4.04s	remaining: 1.9s
# 680:	learn: 2.4936413	total: 4.04s	remaining: 1.89s
# 681:	learn: 2.4935894	total: 4.05s	remaining: 1.89s
# 682:	learn: 2.4935361	total: 4.05s	remaining: 1.88s
# 683:	learn: 2.4934380	total: 4.06s	remaining: 1.87s
# 684:	learn: 2.4934314	total: 4.06s	remaining: 1.87s
# 685:	learn: 2.4933825	total: 4.07s	remaining: 1.86s
# 686:	learn: 2.4932997	total: 4.07s	remaining: 1.85s
# 687:	learn: 2.4932516	total: 4.07s	remaining: 1.85s
# 688:	learn: 2.4931288	total: 4.08s	remaining: 1.84s
# 689:	learn: 2.4930873	total: 4.08s	remaining: 1.83s
# 690:	learn: 2.4929612	total: 4.09s	remaining: 1.83s
# 691:	learn: 2.4929552	total: 4.09s	remaining: 1.82s
# 692:	learn: 2.4929389	total: 4.09s	remaining: 1.81s
# 693:	learn: 2.4928495	total: 4.1s	remaining: 1.81s
# 694:	learn: 2.4926259	total: 4.11s	remaining: 1.8s
# 695:	learn: 2.4925835	total: 4.11s	remaining: 1.8s
# 696:	learn: 2.4924934	total: 4.12s	remaining: 1.79s
# 697:	learn: 2.4923824	total: 4.13s	remaining: 1.78s
# 698:	learn: 2.4923276	total: 4.13s	remaining: 1.78s
# 699:	learn: 2.4922125	total: 4.14s	remaining: 1.77s
# 700:	learn: 2.4921255	total: 4.15s	remaining: 1.77s
# 701:	learn: 2.4920286	total: 4.16s	remaining: 1.76s
# 702:	learn: 2.4919626	total: 4.16s	remaining: 1.76s
# 703:	learn: 2.4918718	total: 4.17s	remaining: 1.75s
# 704:	learn: 2.4917746	total: 4.17s	remaining: 1.75s
# 705:	learn: 2.4916769	total: 4.18s	remaining: 1.74s
# 706:	learn: 2.4915743	total: 4.19s	remaining: 1.74s
# 707:	learn: 2.4914949	total: 4.2s	remaining: 1.73s
# 708:	learn: 2.4914317	total: 4.21s	remaining: 1.73s
# 709:	learn: 2.4914104	total: 4.21s	remaining: 1.72s
# 710:	learn: 2.4913058	total: 4.21s	remaining: 1.71s
# 711:	learn: 2.4911869	total: 4.22s	remaining: 1.71s
# 712:	learn: 2.4911037	total: 4.22s	remaining: 1.7s
# 713:	learn: 2.4910755	total: 4.22s	remaining: 1.69s
# 714:	learn: 2.4910287	total: 4.23s	remaining: 1.69s
# 715:	learn: 2.4909671	total: 4.23s	remaining: 1.68s
# 716:	learn: 2.4908886	total: 4.24s	remaining: 1.67s
# 717:	learn: 2.4907836	total: 4.25s	remaining: 1.67s
# 718:	learn: 2.4907338	total: 4.25s	remaining: 1.66s
# 719:	learn: 2.4905883	total: 4.26s	remaining: 1.66s
# 720:	learn: 2.4905117	total: 4.26s	remaining: 1.65s
# 721:	learn: 2.4902737	total: 4.27s	remaining: 1.64s
# 722:	learn: 2.4902368	total: 4.28s	remaining: 1.64s
# 723:	learn: 2.4901343	total: 4.29s	remaining: 1.63s
# 724:	learn: 2.4900604	total: 4.29s	remaining: 1.63s
# 725:	learn: 2.4899871	total: 4.3s	remaining: 1.62s
# 726:	learn: 2.4899009	total: 4.3s	remaining: 1.61s
# 727:	learn: 2.4898772	total: 4.31s	remaining: 1.61s
# 728:	learn: 2.4897991	total: 4.32s	remaining: 1.6s
# 729:	learn: 2.4896504	total: 4.33s	remaining: 1.6s
# 730:	learn: 2.4896156	total: 4.33s	remaining: 1.59s
# 731:	learn: 2.4895034	total: 4.34s	remaining: 1.59s
# 732:	learn: 2.4894093	total: 4.35s	remaining: 1.58s
# 733:	learn: 2.4892928	total: 4.36s	remaining: 1.58s
# 734:	learn: 2.4891417	total: 4.37s	remaining: 1.57s
# 735:	learn: 2.4890965	total: 4.38s	remaining: 1.57s
# 736:	learn: 2.4889794	total: 4.38s	remaining: 1.56s
# 737:	learn: 2.4889657	total: 4.39s	remaining: 1.56s
# 738:	learn: 2.4889534	total: 4.4s	remaining: 1.55s
# 739:	learn: 2.4888312	total: 4.41s	remaining: 1.55s
# 740:	learn: 2.4888154	total: 4.42s	remaining: 1.54s
# 741:	learn: 2.4886306	total: 4.42s	remaining: 1.54s
# 742:	learn: 2.4885336	total: 4.43s	remaining: 1.53s
# 743:	learn: 2.4884715	total: 4.43s	remaining: 1.52s
# 744:	learn: 2.4883416	total: 4.45s	remaining: 1.52s
# 745:	learn: 2.4882871	total: 4.47s	remaining: 1.52s
# 746:	learn: 2.4882434	total: 4.48s	remaining: 1.52s
# 747:	learn: 2.4881804	total: 4.49s	remaining: 1.51s
# 748:	learn: 2.4881332	total: 4.49s	remaining: 1.5s
# 749:	learn: 2.4881255	total: 4.5s	remaining: 1.5s
# 750:	learn: 2.4880352	total: 4.51s	remaining: 1.49s
# 751:	learn: 2.4879027	total: 4.51s	remaining: 1.49s
# 752:	learn: 2.4878313	total: 4.52s	remaining: 1.48s
# 753:	learn: 2.4877777	total: 4.53s	remaining: 1.48s
# 754:	learn: 2.4876807	total: 4.53s	remaining: 1.47s
# 755:	learn: 2.4876229	total: 4.54s	remaining: 1.46s
# 756:	learn: 2.4875995	total: 4.54s	remaining: 1.46s
# 757:	learn: 2.4875868	total: 4.54s	remaining: 1.45s
# 758:	learn: 2.4875353	total: 4.55s	remaining: 1.44s
# 759:	learn: 2.4875304	total: 4.55s	remaining: 1.44s
# 760:	learn: 2.4874646	total: 4.56s	remaining: 1.43s
# 761:	learn: 2.4873341	total: 4.56s	remaining: 1.42s
# 762:	learn: 2.4872546	total: 4.57s	remaining: 1.42s
# 763:	learn: 2.4872002	total: 4.57s	remaining: 1.41s
# 764:	learn: 2.4871134	total: 4.57s	remaining: 1.41s
# 765:	learn: 2.4869568	total: 4.58s	remaining: 1.4s
# 766:	learn: 2.4868567	total: 4.58s	remaining: 1.39s
# 767:	learn: 2.4867119	total: 4.59s	remaining: 1.39s
# 768:	learn: 2.4865910	total: 4.59s	remaining: 1.38s
# 769:	learn: 2.4865268	total: 4.59s	remaining: 1.37s
# 770:	learn: 2.4864911	total: 4.6s	remaining: 1.37s
# 771:	learn: 2.4864409	total: 4.61s	remaining: 1.36s
# 772:	learn: 2.4864305	total: 4.61s	remaining: 1.35s
# 773:	learn: 2.4863794	total: 4.61s	remaining: 1.35s
# 774:	learn: 2.4862041	total: 4.62s	remaining: 1.34s
# 775:	learn: 2.4861942	total: 4.62s	remaining: 1.33s
# 776:	learn: 2.4861900	total: 4.63s	remaining: 1.33s
# 777:	learn: 2.4861340	total: 4.63s	remaining: 1.32s
# 778:	learn: 2.4860161	total: 4.63s	remaining: 1.31s
# 779:	learn: 2.4859884	total: 4.64s	remaining: 1.31s
# 780:	learn: 2.4859723	total: 4.64s	remaining: 1.3s
# 781:	learn: 2.4859037	total: 4.66s	remaining: 1.3s
# 782:	learn: 2.4858598	total: 4.67s	remaining: 1.29s
# 783:	learn: 2.4857802	total: 4.67s	remaining: 1.29s
# 784:	learn: 2.4856920	total: 4.68s	remaining: 1.28s
# 785:	learn: 2.4855744	total: 4.69s	remaining: 1.28s
# 786:	learn: 2.4854937	total: 4.69s	remaining: 1.27s
# 787:	learn: 2.4854328	total: 4.7s	remaining: 1.26s
# 788:	learn: 2.4853003	total: 4.7s	remaining: 1.26s
# 789:	learn: 2.4852572	total: 4.71s	remaining: 1.25s
# 790:	learn: 2.4851712	total: 4.71s	remaining: 1.25s
# 791:	learn: 2.4851150	total: 4.72s	remaining: 1.24s
# 792:	learn: 2.4849720	total: 4.72s	remaining: 1.23s
# 793:	learn: 2.4849087	total: 4.72s	remaining: 1.23s
# 794:	learn: 2.4848573	total: 4.73s	remaining: 1.22s
# 795:	learn: 2.4847720	total: 4.73s	remaining: 1.21s
# 796:	learn: 2.4846845	total: 4.74s	remaining: 1.21s
# 797:	learn: 2.4845435	total: 4.74s	remaining: 1.2s
# 798:	learn: 2.4844178	total: 4.75s	remaining: 1.19s
# 799:	learn: 2.4843362	total: 4.76s	remaining: 1.19s
# 800:	learn: 2.4843244	total: 4.76s	remaining: 1.18s
# 801:	learn: 2.4842977	total: 4.77s	remaining: 1.18s
# 802:	learn: 2.4841922	total: 4.8s	remaining: 1.18s
# 803:	learn: 2.4841346	total: 4.81s	remaining: 1.17s
# 804:	learn: 2.4841263	total: 4.84s	remaining: 1.17s
# 805:	learn: 2.4839693	total: 4.85s	remaining: 1.17s
# 806:	learn: 2.4838831	total: 4.86s	remaining: 1.16s
# 807:	learn: 2.4837573	total: 4.86s	remaining: 1.16s
# 808:	learn: 2.4836883	total: 4.87s	remaining: 1.15s
# 809:	learn: 2.4836078	total: 4.87s	remaining: 1.14s
# 810:	learn: 2.4836035	total: 4.88s	remaining: 1.14s
# 811:	learn: 2.4836001	total: 4.89s	remaining: 1.13s
# 812:	learn: 2.4834997	total: 4.91s	remaining: 1.13s
# 813:	learn: 2.4834333	total: 4.92s	remaining: 1.12s
# 814:	learn: 2.4833293	total: 4.93s	remaining: 1.12s
# 815:	learn: 2.4832736	total: 4.94s	remaining: 1.11s
# 816:	learn: 2.4832046	total: 4.95s	remaining: 1.11s
# 817:	learn: 2.4831918	total: 4.96s	remaining: 1.1s
# 818:	learn: 2.4830867	total: 4.97s	remaining: 1.1s
# 819:	learn: 2.4830392	total: 4.99s	remaining: 1.09s
# 820:	learn: 2.4830046	total: 5s	remaining: 1.09s
# 821:	learn: 2.4829566	total: 5.01s	remaining: 1.08s
# 822:	learn: 2.4828684	total: 5.01s	remaining: 1.08s
# 823:	learn: 2.4827920	total: 5.02s	remaining: 1.07s
# 824:	learn: 2.4827013	total: 5.03s	remaining: 1.07s
# 825:	learn: 2.4826432	total: 5.04s	remaining: 1.06s
# 826:	learn: 2.4826231	total: 5.05s	remaining: 1.06s
# 827:	learn: 2.4826145	total: 5.06s	remaining: 1.05s
# 828:	learn: 2.4824215	total: 5.07s	remaining: 1.04s
# 829:	learn: 2.4824035	total: 5.08s	remaining: 1.04s
# 830:	learn: 2.4823845	total: 5.09s	remaining: 1.03s
# 831:	learn: 2.4823018	total: 5.1s	remaining: 1.03s
# 832:	learn: 2.4822321	total: 5.11s	remaining: 1.02s
# 833:	learn: 2.4821508	total: 5.14s	remaining: 1.02s
# 834:	learn: 2.4819527	total: 5.15s	remaining: 1.02s
# 835:	learn: 2.4819136	total: 5.15s	remaining: 1.01s
# 836:	learn: 2.4819033	total: 5.16s	remaining: 1s
# 837:	learn: 2.4818240	total: 5.17s	remaining: 1000ms
# 838:	learn: 2.4817420	total: 5.18s	remaining: 994ms
# 839:	learn: 2.4817292	total: 5.19s	remaining: 988ms
# 840:	learn: 2.4817118	total: 5.2s	remaining: 983ms
# 841:	learn: 2.4816522	total: 5.21s	remaining: 977ms
# 842:	learn: 2.4815672	total: 5.22s	remaining: 972ms
# 843:	learn: 2.4814508	total: 5.23s	remaining: 966ms
# 844:	learn: 2.4814347	total: 5.24s	remaining: 961ms
# 845:	learn: 2.4814232	total: 5.25s	remaining: 955ms
# 846:	learn: 2.4813032	total: 5.26s	remaining: 949ms
# 847:	learn: 2.4812919	total: 5.26s	remaining: 944ms
# 848:	learn: 2.4812549	total: 5.27s	remaining: 938ms
# 849:	learn: 2.4812340	total: 5.28s	remaining: 932ms
# 850:	learn: 2.4811674	total: 5.29s	remaining: 927ms
# 851:	learn: 2.4810946	total: 5.3s	remaining: 921ms
# 852:	learn: 2.4810499	total: 5.31s	remaining: 916ms
# 853:	learn: 2.4809838	total: 5.32s	remaining: 910ms
# 854:	learn: 2.4809028	total: 5.33s	remaining: 904ms
# 855:	learn: 2.4807755	total: 5.34s	remaining: 898ms
# 856:	learn: 2.4806510	total: 5.35s	remaining: 893ms
# 857:	learn: 2.4805782	total: 5.36s	remaining: 887ms
# 858:	learn: 2.4804914	total: 5.37s	remaining: 881ms
# 859:	learn: 2.4804103	total: 5.38s	remaining: 876ms
# 860:	learn: 2.4803773	total: 5.38s	remaining: 869ms
# 861:	learn: 2.4803424	total: 5.39s	remaining: 863ms
# 862:	learn: 2.4802630	total: 5.4s	remaining: 857ms
# 863:	learn: 2.4801673	total: 5.41s	remaining: 851ms
# 864:	learn: 2.4800168	total: 5.41s	remaining: 845ms
# 865:	learn: 2.4799214	total: 5.42s	remaining: 839ms
# 866:	learn: 2.4798985	total: 5.43s	remaining: 832ms
# 867:	learn: 2.4798869	total: 5.43s	remaining: 826ms
# 868:	learn: 2.4798789	total: 5.44s	remaining: 820ms
# 869:	learn: 2.4797765	total: 5.44s	remaining: 813ms
# 870:	learn: 2.4796631	total: 5.45s	remaining: 807ms
# 871:	learn: 2.4796553	total: 5.46s	remaining: 801ms
# 872:	learn: 2.4795887	total: 5.46s	remaining: 794ms
# 873:	learn: 2.4795779	total: 5.47s	remaining: 788ms
# 874:	learn: 2.4795624	total: 5.47s	remaining: 782ms
# 875:	learn: 2.4795125	total: 5.47s	remaining: 775ms
# 876:	learn: 2.4794747	total: 5.48s	remaining: 769ms
# 877:	learn: 2.4793420	total: 5.49s	remaining: 763ms
# 878:	learn: 2.4792369	total: 5.51s	remaining: 758ms
# 879:	learn: 2.4791663	total: 5.52s	remaining: 752ms
# 880:	learn: 2.4791571	total: 5.52s	remaining: 746ms
# 881:	learn: 2.4790686	total: 5.53s	remaining: 740ms
# 882:	learn: 2.4790073	total: 5.54s	remaining: 733ms
# 883:	learn: 2.4789570	total: 5.54s	remaining: 727ms
# 884:	learn: 2.4788655	total: 5.55s	remaining: 721ms
# 885:	learn: 2.4787680	total: 5.55s	remaining: 715ms
# 886:	learn: 2.4786502	total: 5.56s	remaining: 708ms
# 887:	learn: 2.4786125	total: 5.57s	remaining: 702ms
# 888:	learn: 2.4785552	total: 5.57s	remaining: 696ms
# 889:	learn: 2.4784302	total: 5.58s	remaining: 689ms
# 890:	learn: 2.4783571	total: 5.58s	remaining: 683ms
# 891:	learn: 2.4782735	total: 5.59s	remaining: 677ms
# 892:	learn: 2.4781784	total: 5.59s	remaining: 670ms
# 893:	learn: 2.4781680	total: 5.6s	remaining: 664ms
# 894:	learn: 2.4781576	total: 5.61s	remaining: 658ms
# 895:	learn: 2.4780939	total: 5.62s	remaining: 652ms
# 896:	learn: 2.4780847	total: 5.62s	remaining: 646ms
# 897:	learn: 2.4780266	total: 5.63s	remaining: 640ms
# 898:	learn: 2.4779523	total: 5.64s	remaining: 634ms
# 899:	learn: 2.4778822	total: 5.65s	remaining: 628ms
# 900:	learn: 2.4778748	total: 5.66s	remaining: 622ms
# 901:	learn: 2.4778658	total: 5.67s	remaining: 616ms
# 902:	learn: 2.4778250	total: 5.67s	remaining: 609ms
# 903:	learn: 2.4777814	total: 5.68s	remaining: 603ms
# 904:	learn: 2.4777485	total: 5.69s	remaining: 597ms
# 905:	learn: 2.4776847	total: 5.7s	remaining: 591ms
# 906:	learn: 2.4776777	total: 5.71s	remaining: 585ms
# 907:	learn: 2.4775186	total: 5.71s	remaining: 579ms
# 908:	learn: 2.4774785	total: 5.72s	remaining: 573ms
# 909:	learn: 2.4774148	total: 5.73s	remaining: 567ms
# 910:	learn: 2.4773816	total: 5.73s	remaining: 560ms
# 911:	learn: 2.4772696	total: 5.74s	remaining: 554ms
# 912:	learn: 2.4770216	total: 5.74s	remaining: 547ms
# 913:	learn: 2.4769412	total: 5.74s	remaining: 541ms
# 914:	learn: 2.4768439	total: 5.75s	remaining: 534ms
# 915:	learn: 2.4768307	total: 5.75s	remaining: 527ms
# 916:	learn: 2.4768022	total: 5.75s	remaining: 521ms
# 917:	learn: 2.4767979	total: 5.76s	remaining: 514ms
# 918:	learn: 2.4767142	total: 5.76s	remaining: 508ms
# 919:	learn: 2.4766257	total: 5.77s	remaining: 501ms
# 920:	learn: 2.4765681	total: 5.77s	remaining: 495ms
# 921:	learn: 2.4764914	total: 5.77s	remaining: 488ms
# 922:	learn: 2.4763820	total: 5.78s	remaining: 482ms
# 923:	learn: 2.4762670	total: 5.78s	remaining: 476ms
# 924:	learn: 2.4761409	total: 5.79s	remaining: 469ms
# 925:	learn: 2.4760727	total: 5.79s	remaining: 463ms
# 926:	learn: 2.4759905	total: 5.79s	remaining: 456ms
# 927:	learn: 2.4759212	total: 5.8s	remaining: 450ms
# 928:	learn: 2.4758606	total: 5.8s	remaining: 443ms
# 929:	learn: 2.4757660	total: 5.8s	remaining: 437ms
# 930:	learn: 2.4757513	total: 5.81s	remaining: 431ms
# 931:	learn: 2.4757030	total: 5.81s	remaining: 424ms
# 932:	learn: 2.4756026	total: 5.82s	remaining: 418ms
# 933:	learn: 2.4754791	total: 5.82s	remaining: 411ms
# 934:	learn: 2.4754407	total: 5.82s	remaining: 405ms
# 935:	learn: 2.4754304	total: 5.83s	remaining: 398ms
# 936:	learn: 2.4752400	total: 5.83s	remaining: 392ms
# 937:	learn: 2.4751281	total: 5.83s	remaining: 386ms
# 938:	learn: 2.4749993	total: 5.84s	remaining: 379ms
# 939:	learn: 2.4749898	total: 5.84s	remaining: 373ms
# 940:	learn: 2.4749854	total: 5.85s	remaining: 367ms
# 941:	learn: 2.4749044	total: 5.85s	remaining: 360ms
# 942:	learn: 2.4747869	total: 5.86s	remaining: 354ms
# 943:	learn: 2.4747045	total: 5.86s	remaining: 348ms
# 944:	learn: 2.4746684	total: 5.86s	remaining: 341ms
# 945:	learn: 2.4746024	total: 5.87s	remaining: 335ms
# 946:	learn: 2.4745634	total: 5.87s	remaining: 329ms
# 947:	learn: 2.4745116	total: 5.87s	remaining: 322ms
# 948:	learn: 2.4744070	total: 5.88s	remaining: 316ms
# 949:	learn: 2.4743955	total: 5.88s	remaining: 310ms
# 950:	learn: 2.4743671	total: 5.88s	remaining: 303ms
# 951:	learn: 2.4742444	total: 5.89s	remaining: 297ms
# 952:	learn: 2.4741612	total: 5.89s	remaining: 291ms
# 953:	learn: 2.4740273	total: 5.9s	remaining: 284ms
# 954:	learn: 2.4739256	total: 5.9s	remaining: 278ms
# 955:	learn: 2.4739177	total: 5.91s	remaining: 272ms
# 956:	learn: 2.4738610	total: 5.91s	remaining: 266ms
# 957:	learn: 2.4738100	total: 5.91s	remaining: 259ms
# 958:	learn: 2.4737368	total: 5.92s	remaining: 253ms
# 959:	learn: 2.4736512	total: 5.92s	remaining: 247ms
# 960:	learn: 2.4735860	total: 5.92s	remaining: 240ms
# 961:	learn: 2.4735372	total: 5.93s	remaining: 234ms
# 962:	learn: 2.4733704	total: 5.93s	remaining: 228ms
# 963:	learn: 2.4733233	total: 5.94s	remaining: 222ms
# 964:	learn: 2.4731815	total: 5.94s	remaining: 215ms
# 965:	learn: 2.4730887	total: 5.94s	remaining: 209ms
# 966:	learn: 2.4730387	total: 5.95s	remaining: 203ms
# 967:	learn: 2.4728964	total: 5.95s	remaining: 197ms
# 968:	learn: 2.4728934	total: 5.95s	remaining: 190ms
# 969:	learn: 2.4728303	total: 5.96s	remaining: 184ms
# 970:	learn: 2.4727386	total: 5.96s	remaining: 178ms
# 971:	learn: 2.4727069	total: 5.96s	remaining: 172ms
# 972:	learn: 2.4725620	total: 5.97s	remaining: 166ms
# 973:	learn: 2.4725260	total: 5.97s	remaining: 159ms
# 974:	learn: 2.4723938	total: 5.98s	remaining: 153ms
# 975:	learn: 2.4722832	total: 5.99s	remaining: 147ms
# 976:	learn: 2.4722430	total: 6s	remaining: 141ms
# 977:	learn: 2.4721766	total: 6s	remaining: 135ms
# 978:	learn: 2.4720733	total: 6.01s	remaining: 129ms
# 979:	learn: 2.4719597	total: 6.01s	remaining: 123ms
# 980:	learn: 2.4718780	total: 6.02s	remaining: 117ms
# 981:	learn: 2.4717817	total: 6.03s	remaining: 110ms
# 982:	learn: 2.4716359	total: 6.03s	remaining: 104ms
# 983:	learn: 2.4716331	total: 6.04s	remaining: 98.2ms
# 984:	learn: 2.4715428	total: 6.04s	remaining: 92ms
# 985:	learn: 2.4715079	total: 6.05s	remaining: 85.9ms
# 986:	learn: 2.4714155	total: 6.06s	remaining: 79.8ms
# 987:	learn: 2.4713797	total: 6.06s	remaining: 73.6ms
# 988:	learn: 2.4712956	total: 6.07s	remaining: 67.5ms
# 989:	learn: 2.4712286	total: 6.08s	remaining: 61.4ms
# 990:	learn: 2.4711755	total: 6.08s	remaining: 55.2ms
# 991:	learn: 2.4711683	total: 6.09s	remaining: 49.1ms
# 992:	learn: 2.4710691	total: 6.1s	remaining: 43ms
# 993:	learn: 2.4710367	total: 6.11s	remaining: 36.9ms
# 994:	learn: 2.4709505	total: 6.12s	remaining: 30.7ms
# 995:	learn: 2.4708588	total: 6.12s	remaining: 24.6ms
# 996:	learn: 2.4707320	total: 6.13s	remaining: 18.4ms
# 997:	learn: 2.4706039	total: 6.14s	remaining: 12.3ms
# 998:	learn: 2.4705955	total: 6.15s	remaining: 6.15ms
# 999:	learn: 2.4705815	total: 6.15s	remaining: 0us
# Mean Squared Error: 8.078655132503487

# %%
from sklearn.model_selection import train_test_split
df = df.set_index('date')
insample_data = df['2020-01-01':'2022-06-30']
outsample_data = df['2022-07-01':'2022-11-30']
train_date, test_date = train_test_split(insample_data.index.unique(), test_size=0.1)
train_data = insample_data.loc[train_date]
test_data = insample_data.loc[test_date]

# %%
import lightgbm as lgb
from itertools import product

param_grid = {
    'subsample': [0.6, 0.7],
    'max_depth': [3, 4]
}

search_space = list(map(lambda x: dict(zip(param_grid.keys(), x)), list(product(*param_grid.values()))))

train_X = train_data.iloc[:, 1:-1]
train_y = train_data.iloc[:, -1]

test_X = test_data.iloc[:, 1:-1]
test_y = test_data.iloc[:, -1]

test_ic_data = test_data[['code', 'target']]

def cross_ic(y_true, y_pred):
    true_y = test_ic_data.copy()
    true_y['target'] = y_true
    true_y = true_y.reset_index().pivot(index='date', columns='code', values='target')
    pred_y = test_ic_data.copy()
    pred_y['target'] = y_pred
    pred_y = pred_y.reset_index().pivot(index='date', columns='code', values='target')
    return true_y.corrwith(pred_y).mean()

best_params = None
best_estimator = None
best_ic = 0

for param in search_space:
    gbdt_params = {
                    'boosting_type': 'gbdt',
                    'objective': 'regression',
                    'metric': {'l2', 'l1'},
                    'num_leaves': 31,
                    'learning_rate': 0.1,
                    'feature_fraction': 0.9,
                    'bagging_fraction':param['subsample'],
                    'bagging_freq': 5,
                    'max_depth':param['max_depth'],
                    'verbose': 1
                    }   
    lgb_train = lgb.Dataset(train_X, train_y)
    gbm = lgb.train(gbdt_params,
                lgb_train,
                valid_sets=lgb_train,
                num_boost_round=50)

# 预测
    y_pred = gbm.predict(test_X, num_iteration=gbm.best_iteration)
    ic = cross_ic(test_y, y_pred)
    print(f"{param}-ic: {ic}")
    if abs(ic) > best_ic:
        best_ic = ic
        best_params = param
        best_estimator = gbm
        
print("最佳参数组合:", best_params)
print("最佳模型:", best_estimator)
print("最佳IC:", best_ic)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.016347 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 2291663, number of used features: 9
# [LightGBM] [Info] Start training from score 0.014439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'subsample': 0.6, 'max_depth': 3}-ic: 0.054946482088115874
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.057411 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 2291663, number of used features: 9
# [LightGBM] [Info] Start training from score 0.014439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'subsample': 0.6, 'max_depth': 4}-ic: 0.056717482896612964
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012736 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 2291663, number of used features: 9
# [LightGBM] [Info] Start training from score 0.014439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'subsample': 0.7, 'max_depth': 3}-ic: 0.05730480651753225
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013286 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 2291663, number of used features: 9
# [LightGBM] [Info] Start training from score 0.014439
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'subsample': 0.7, 'max_depth': 4}-ic: 0.05835726843303796
# 最佳参数组合: {'subsample': 0.7, 'max_depth': 4}
# 最佳模型: <lightgbm.basic.Booster object at 0x7f57ded72c20>
# 最佳IC: 0.05835726843303796

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import time
import glob
import warnings
warnings.filterwarnings('ignore')


#data
path = "./data/factor_vp"
all_files = glob.glob(path + "/*.csv")   #把所有的数据文件文件名读取在一起
li = []
#

for filename in tqdm(all_files):
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)


frame = pd.concat(li, axis=0, ignore_index=True)
path1 = "./data/data_test"
all_files1 = glob.glob(path1 + "/*.csv")

li1 = []
for filename in tqdm(all_files1):
    df1 = pd.read_csv(filename)  # 读取CSV文件
    # 提取需要的列
    df_subset  = df1[['date', 'code', '1vwap_pct']]
    li1.append(df_subset)

# 合并数据到 factor_vp
frame1 = pd.concat(li1, axis=0, ignore_index=True)
# 将frame1中的1vwap_pct列拼接到frame中
#frame = pd.merge(frame, frame1, on=['date', 'code'], how='left')
frame['1vwap_pct']= frame1['1vwap_pct']
# 删去frame中日期大于2022-12-31的数据
frame = frame[frame['date'] <= '2022-12-31']
path2 = "./data/UTR_final2"
all_files2 = glob.glob(path2 + "/*.csv")
li2 = []
for filename in tqdm(all_files2):
    df2 = pd.read_csv(filename)  # 读取CSV文件
    df_subset2 = df2[['code', 'UTR_resid']]
    li2.append(df_subset2)
frame2 = pd.concat(li2, axis=0, ignore_index=True)

frame['UTR_resid'] = frame2['UTR_resid']
path3 = "./data/data_barra"
all_files3 = glob.glob(path3 + "/*.csv")
li3 = []
for filename in tqdm(all_files3):
    df3 = pd.read_csv(filename)  # 读取CSV文件
    df_subset3 = df3[['code', 'beta','momentum','residual_volatility','non_linear_size','book_to_price_ratio','liquidity','earnings_yield','growth','leverage']]
    li3.append(df_subset3)
frame3 = pd.concat(li3, axis=0, ignore_index=True)
frame['beta'] = frame3['beta']
frame['momentum'] = frame3['momentum']
frame['residual_volatility'] = frame3['residual_volatility']
frame['non_linear_size'] = frame3['non_linear_size']
frame['book_to_price_ratio'] = frame3['book_to_price_ratio']
frame['liquidity'] = frame3['liquidity']
frame['earnings_yield'] = frame3['earnings_yield']
frame['growth'] = frame3['growth']
frame['leverage'] = frame3['leverage']
result_df = frame.sort_values(by=['date', 'code'], ascending=True)
#result_df['vwap'] = result_df['money'] / result_df['volume']
result_df['target'] = result_df.groupby('code')['1vwap_pct'].shift(-1).values
df = result_df.reset_index(drop=True)
df = df.fillna(0)
df_train = df[(df['date'] <= '2022-02-01')]
df_val = df[(df['date'] > '2022-02-01') & (df['date']<='2022-04-30')]
df_test = df[(df['date'] <= '2022-12-29') & (df['date'] >= '2022-05-01')]
#df_train = df[(df['date'] >= '2022-11-31') & (df['date'] <= '2022-12-22')]
#df_val = df[(df['date'] <= '2022-12-25') & (df['date'] >= '2022-12-23')]
#df_test = df[(df['date'] <= '2022-12-29') & (df['date'] >= '2022-12-26')]
X_train = df_train[['boll_down','boll_up','BIAS1M','ROC1M','day_VPT','close_std_1M','vol_std_6M','vol_me_6M','Amihud','UTR_resid','beta','momentum','residual_volatility','non_linear_size','book_to_price_ratio','liquidity','earnings_yield','growth','leverage']].values
y_train = df_train[['target']].values
X_val = df_val[['boll_down','boll_up','BIAS1M','ROC1M','day_VPT','close_std_1M','vol_std_6M','vol_me_6M','Amihud','UTR_resid','beta','momentum','residual_volatility','non_linear_size','book_to_price_ratio','liquidity','earnings_yield','growth','leverage']].values
y_val = df_val[['target']].values
X_test = df_test[['boll_down','boll_up','BIAS1M','ROC1M','day_VPT','close_std_1M','vol_std_6M','vol_me_6M','Amihud','UTR_resid','beta','momentum','residual_volatility','non_linear_size','book_to_price_ratio','liquidity','earnings_yield','growth','leverage']].values
y_test = df_test[['target']].values
